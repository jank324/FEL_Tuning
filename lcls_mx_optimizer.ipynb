# %%
import os

import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from bayes_opt import BayesianOptimization
from pmd_beamphysics import ParticleGroup
from pmd_beamphysics.statistics import slice_statistics
from pytao import Tao

from constants import K_u, lambda_u, markers, z
from fel_mx_model import (
    Pbeam,
    Psat,
    gainLength,
    gainLength1D,
    getLambdaMX,
    resonantLambda,
    rhoFEL,
    shot_noise,
)

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
matplotlib.rcParams['figure.figsize'] = (8,4)
plt.rcParams.update({'font.size': 14})

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Initialize Tao

# %%
# create ParticleGroup from bmad h5 particle data
directory = "./beam_undulator_data/"

save_beam = False

l1_phase_init, l1x_phase_init, l2_phase_init = -21.5, -160.0, -33.5

# %% [markdown]
# ### Change input params functions for objective

# %%
def beamOn(n_particle, l1_phase, l1x_phase, l2_phase):
    print(f"JAN BEAM_ON ... snparticle {n_particle}")
    tao.cmd(f"snparticle {n_particle}")
    print("JAN BEAM_ON ... beamon")
    tao.cmd("beamon")

    # collimator to get rid of horns// no need with wakes off??
    # tao.cmd('set ele CE11 x1_limit = 0.0015 ;set ele CE11 x2_limit = 0.0035')
    # tao.cmd('set ele CE21 x1_limit = 0.0009; set ele CE11 x2_limit = 0.0035;')
    # tao.cmd('set ele CE21 x1_limit = 0.0007; set ele CE11 x2_limit = 0.0035;')

    print(f"JAN BEAM_ON ... set ele O_L1 phase_deg={l1_phase}")

    # start with L1, L1X and L2 phases
    tao.cmd(f"set ele O_L1 phase_deg={l1_phase}")
    print(f"JAN BEAM_ON ... set ele K21_2 phase_deg={l1x_phase}")
    tao.cmd(f"set ele K21_2 phase_deg={l1x_phase}")
    print(f"JAN BEAM_ON ... set ele O_L2 phase_deg={l2_phase}")
    tao.cmd(f"set ele O_L2 phase_deg={l2_phase}")
    print("JAN BEAM_ON --- DONE ---")

# %%
def saveBeam():
    # timestamp = '07-07_10-30'
    # timestamp = '08-08_10-30'
    # timestamp = (datetime.datetime.now()).strftime("%m-%d_%H-%M")
    timestamp = "08-15_17-39"
    # need to log settings for bmad somewhere here?

    # Beam data along undulator
    P_data = {}

    # write beam at each marker in undulator
    for i, marker in enumerate(markers):
        tao.cmd(
            "write beam -at"
            f" {marker} ./beam_undulator_data/lcls_beam_{i}_{marker}_{timestamp}.h5"
        )

    # need to figure out how to pass it here without h5 files to make it faster?
    for i, marker in enumerate(markers):
        filename = f"lcls_beam_{i}_{marker}_{timestamp}.h5"
        P_data[f"{marker}"] = ParticleGroup(directory + filename)

    # collimation loses some particles, take only alive particles here
    for beam in P_data:
        P_data[beam] = P_data[beam].where(P_data[beam].status == 1)  # status 1 is alive
        n_part_alive = P_data[beam].n_alive

    if save_beam == False:
        os.system(f"rm -f ./beam_undulator_data/lcls_beam_*_{timestamp}.h5")
    return P_data, n_part_alive

# %% [markdown]
# ### util fns

# %%
def create_bins(lower_bound, width, quantity):
    """create_bins returns an equal-width (distance) partitioning.
    It returns an ascending list of tuples, representing the intervals.
    A tuple bins[i], i.e. (bins[i][0], bins[i][1])  with i > 0
    and i < quantity, satisfies the following conditions:
        (1) bins[i][0] + width == bins[i][1]
        (2) bins[i-1][0] + width == bins[i][0] and
            bins[i-1][1] + width == bins[i][1]
    """
    bins = []
    for low in range(lower_bound, lower_bound + quantity * width + 1, width):
        bins.append((low, low + width))
    return bins


def find_bin(value, bins):
    """bins is a list of tuples, like [(0,20), (20, 40), (40, 60)],
    binning returns the smallest index i of bins so that
    bin[i][0] <= value < bin[i][1]
    """

    for i in range(0, len(bins)):
        if bins[i][0] <= value < bins[i][1]:
            return i
    return -1

# %%
# init outside loop for the runtime error
init = "-init ./tao.init -noplot"
# Make tao instance
tao = Tao(init)

# %% [markdown]
# # Objective measurement is full Psat calc below

# %%
# try to cut based on P vals from P_data
# P_data_edited = np.where(P_data['VVHXU19']['delta_t']< P_data['VVHXU19']['delta_t'][np.argmin(P_data['VVHXU19']['delta_pz'])], P_data['VVHXU19']['delta_pz'], P_data['VVHXU19']['delta_pz']*0 )

# %%
def evaluate(var1, var1x, var2):
    print(f"JAN -> {var1 = }, {var1x = }, {var2 = }")
    # init outside loop for the runtime error
    # init = "-init ./tao.init -noplot"
    # Make tao instance
    # tao = Tao(init)

    print(f"JAN Tao beamOn")
    try:
        # n_particle, l1_phase, l1x_phase, l2_phase
        beamOn(1500, var1, var1x, var2)
    except RuntimeError:
        print("Passing RuntimeError")
        pass

    print(f"JAN Tao saveBeam")
    P_data, n_part_alive = saveBeam()
    print(f"JAN -> {P_data = }")
    print(f"JAN -> {n_part_alive = }")
    ###############
    # plot example
    P_data["VVHXU20"].plot("delta_t", "delta_pz")  # JAN changed from VVHXU19 to VVHXU20

    # I NEED TO BREAK THESE UP INTO FUNCTIONS BUT FOR NOW THIS IS FINE
    ################
    slices = {}
    n_slice = int(n_part_alive / 30)  # how to determine denominator automatically?
    print(f"JAN -> {n_slice = }")

    ## getting sliced stats for beam at each marker (along z)
    for i, marker in enumerate(markers):
        P = P_data[f"{marker}"]
        slices[marker] = slice_statistics(
            P,
            keys=[
                "sigma_pz",
                "mean_pz",
                "average_current",
                "norm_emit_x",
                "norm_emit_y",
                "mean_px",
                "mean_x",
                "mean_py",
                "mean_y",
                "sigma_x",
                "sigma_y",
            ],
            n_slice=n_slice,
            slice_key="t",
        )
    print(f"JAN -> {P = }")
    print(f"JAN -> {[(k, v.keys()) for k, v in slices.items()] = }")
    ################
    # fig, ax = plt.subplots(3, sharex=True, figsize=(10,13))
    #     sl = slices["VVHXU19"]

    #     #plt.plot(sl['norm_emit_x']*10**(9), label=r"$\epsilon_x$")
    #     #plt.plot(sl['norm_emit_y']*10**(9), label=r"$\epsilon_y$")
    #     plt.plot(sl['average_current']*10**(-3), label=r"$I_{avg}$")
    #     plt.plot(sl['sigma_pz']*10**(-7), label=r"$\sigma_{p_z}$")
    #     plt.title("Und, collimated")

    #     plt.legend()

    # plt.ylim(0,5)
    ### energy spread is large because of the weird line shaped horns
    #############
    time_slice = (P.t.max() - P.t.min()) / n_slice
    print(f"JAN -> {time_slice = }")
    ##############
    # find 3D gain length
    # instant growth rate (Lg) at each marker for each slice
    lg_slice = []

    for i, marker in enumerate(markers):
        # particle group/slice
        sl = slices[marker]
        P = P_data[marker]

        # emittances
        norm_emit_x = sl["norm_emit_x"]
        norm_emit_y = sl["norm_emit_y"]

        # average current
        current_beam = sl["average_current"]
        # current_beam = 3*1e3 if sl["average_current"][i]>3*1e3 else sl["average_current"][i]

        # energy spread
        sig_pz = sl[
            "sigma_pz"
        ]  # /19 # adjusted just to test, take real one here after fixing horns!!!!!!!!!!!!!
        # sig_pz = [0.5*1e7 if x>0.5*1e7 else x for x in sl["sigma_pz"]] # adjusted just to test, take real one here after fixing horns!!!!!!!!!!!!!
        mean_pz = sl["mean_pz"]

        # gamma relativistic
        gamma_beam = sl["mean_pz"] / P.mass

        # normalization factor for each slice ---> is this correct or is it beta*gamma?????????????????????
        norm_fac_mult = gamma_beam

        # unnormalized emittances
        un_emit_x = norm_emit_x / norm_fac_mult  # [m]
        un_emit_y = norm_emit_y / norm_fac_mult

        # beam sizes
        sig_x = sl["sigma_x"]
        sig_y = sl["sigma_y"]

        # geom size
        sizes = np.sqrt(
            sig_x * sig_y
        )  # check for MX assumptions: assymmetric beam size?????????????????????

        # geom emittance (not normalized)
        emittance = np.sqrt(un_emit_x * un_emit_y)

        # radiation wavelength
        lambda_rad = resonantLambda(gamma_beam, K_u, lambda_u)

        # FEL parameter
        rho = rhoFEL(current_beam, sizes, gamma_beam)

        # get instant. Lg
        Lg1D = gainLength1D(rho, lambda_u)

        # Ming Xie
        LambdaMX = getLambdaMX(
            Lg1D, sizes, lambda_rad, emittance, lambda_u, sig_pz, mean_pz
        )
        Lg = gainLength(Lg1D, LambdaMX)

        # append to list
        lg_slice.append(Lg)

    print(f"JAN -> {[elem.shape for elem in lg_slice] = }")

    ######
    # find z location reached 18Lg
    # Get z distance between markers (dZ)
    dZ = [0] * len(z)
    print(f"JAN -> {len(dZ) = }")
    print(f"JAN -> {len(z) = } vs. {len(markers) = }")

    for i, loc in enumerate(z):
        dz = loc - z[i - 1]

        if dz == 0 or i == 0:
            dz = 0
        dZ[i] = dz
    print(f"JAN -> {z = }")
    print(f"JAN -> {dZ = }")

    lg_cumul_slice = []  # gain lengths so far for each slice
    zsat = []  # z at saturation
    zsat_idx = []  # index of z list at saturation

    for j in range(n_slice):
        fracLgcum = 0
        satQ = False
        list_lg_cum = []  # for each slice get Lg along z

        for i, instLg in enumerate(lg_slice):
            # at this location in und, get number of gain lengths so far
            fracLg = (
                dZ[i] / instLg[j]
            )  # dist since last marker in fractions of Lg at this marker
            Lgcum = fracLg + fracLgcum  # increment to find 18Lg marker location
            fracLgcum = Lgcum
            list_lg_cum.append(Lgcum)

            if fracLgcum > 18 and satQ == False:
                satQ = True
                # print(f"saturated at z = {z[i]}, marker = {markers[i]}")
                zsat.append(z[i])
                zsat_idx.append(i)

        if satQ == False:
            n_slice -= 1
            print(f"slice {j} did not saturate.")

        lg_cumul_slice.append(list_lg_cum)

    print(f"JAN -> {lg_cumul_slice = }")
    print(f"JAN -> {zsat = }")
    print(f"JAN -> {zsat_idx = }")

    #     plt.figure(figsize=(15,7))

    #     for i in range(n_slice):
    #         # plot cumulative Lg for each slice along undulator
    #         plt.plot(z, lg_cumul_slice[i], alpha=0.5)

    #     # saturation point
    #     plt.hlines(18, 0, 160, linestyle="--", color="black", label="Saturation (18L$_g$)")

    #     plt.legend()
    #     plt.ylabel(r"Cumul. L$_g$ [m]");
    #     plt.xlabel("z (m)");

    #############
    # find saturation power
    # get avg Lg for each slice from saturation point
    lg_avg = []

    # for i in range(n_slice): # SOME DON'T SATURATE HERE
    for i in range(len(zsat)):
        lg_avg.append(zsat[i] / 18)  # wait is this correct?

    print(f"JAN -> {lg_avg = }")

    (
        p_shotnoise_list,
        rho_list,
        psat_list,
        mean_pz_list,
        current_list,
        sizes_list,
        lambda_rad_list,
    ) = ([], [], [], [], [], [], [])

    # loop over slices at the point where each saturates
    for i in range(n_slice):
        # z along und where saturation happens

        sl = slices[markers[zsat_idx[i]]]
        P = P_data[markers[zsat_idx[i]]]

        # emittances
        norm_emit_x = sl["norm_emit_x"][i]
        norm_emit_y = sl["norm_emit_y"][i]

        # average current
        current_beam = sl["average_current"][i]
        # current_beam = 3*1e3 if sl["average_current"][i]>3*1e3 else sl["average_current"][i]

        current_list.append(current_beam)

        # energy spread
        sig_pz = sl["sigma_pz"][i]  # /19 # need to adjust later !!!!!!!!!!!!!!!!!!!!!!
        # sig_pz = 0.5*1e7 if sl["sigma_pz"][i]>0.5*1e7 else sl["sigma_pz"][i]
        mean_pz = sl["mean_pz"][i]
        mean_pz_list.append(mean_pz)

        # gamma relativistic
        gamma_beam = sl["mean_pz"][i] / P.mass

        # unnormalized emittances
        un_emit_x = norm_emit_x / norm_fac_mult[i]  # [m]
        un_emit_y = norm_emit_y / norm_fac_mult[i]
        emittance = np.sqrt(un_emit_x * un_emit_y)

        sig_y = sl["sigma_y"][i]
        sig_x = sl["sigma_x"][i]

        sizes = np.sqrt(sig_x * sig_y)
        sizes_list.append(sizes)

        # get inst Lg
        lambda_rad = resonantLambda(gamma_beam, K_u, lambda_u)
        lambda_rad_list.append(lambda_rad)

        rho = rhoFEL(current_beam, sizes, gamma_beam)
        rho_list.append(rho)
        Lg1D = gainLength1D(rho, lambda_u)

        p_shotnoise_list.append(shot_noise(rho, lambda_rad, current_beam, gamma_beam))
        pbeam = Pbeam(gamma_beam, current_beam)

        # not sure if correct to us 3DLg in MX factor?
        LambdaMX = getLambdaMX(
            lg_avg[i], sizes, lambda_rad, emittance, lambda_u, sig_pz, mean_pz
        )
        Lg = lg_avg[i]

        psat_list.append(Psat(LambdaMX, rho, pbeam))  # in GW
        # print(Psat(LambdaMX, rho, pbeam), current_beam/1e3, Pz(shot_noise(rho, lambda_rad, current_beam, gamma_beam), 18))

    min_e = min(mean_pz_list)
    max_e = max(mean_pz_list)
    # (max_e - min_e)/np.mean(mean_pz_list)*100
    # min_e, max_e, (max_e-min_e), int((max_e-min_e))#/bin_size)

    bin_size = 500000
    bins = create_bins(
        lower_bound=int(min_e), width=bin_size, quantity=int((max_e - min_e) / bin_size)
    )

    binned_psat = [0] * len(bins)
    binned_e_phot = [0] * len(bins)
    binned_num_phot = [0] * len(bins)
    en_idx = []

    for i in range(n_slice):
        # find e- energy bin index
        bin_index = find_bin(mean_pz_list[i], bins)
        en_idx.append(bin_index)

        # increment Psat val at that bin index [JOULES]
        binned_psat[bin_index] = (
            binned_psat[bin_index] + psat_list[i] * time_slice * 1e9
        )  ## IN JOULES, from W not GW

        # photons/sec from power: divide by photon energy [W]/[J]= ph/[s]
        # need photon energy corresponding to each electron energy bin

    #     binned_e_phot = constants.h*c/(lambda_rad_list[i]) # [J.s]x[m/s]/m
    #     binned_num_phot[bin_index] = binned_psat[bin_index] / binned_e_phot + binned_num_phot[bin_index]
    #     #binned_num_phot[bin_index] = binned_e_phot/constants.h + binned_num_phot[bin_index]

    ###############
    plt.figure(figsize=(12, 7))

    plt.plot(binned_psat, linewidth=1, marker=".", label="Power [Joules / energy bin]")
    # plt.ylabel("P/energy bin [GW]")

    # plt.plot(en_idx, np.array(current_list)/50, linewidth=0, marker='o', markersize=2, label="Current [kA/50]")
    # plt.plot(en_idx, np.array(psat_list), linewidth=0, marker='x', label="Psat [GW]")

    plt.legend()

    # plt.ylim(0,2000)
    # plt.plot(np.array(binned_num_phot)/1, linewidth=0, marker='x', markersize=5)

    # max 0.6-1.3 E17 photons/pulse -> expected 0.15-14 E12 ---->>> 5 orders of magnitude off
    ###############
    # plt.plot(en_idx, np.array(psat_list), linewidth=0, marker='x', label="Psat [GW]")
    ###############

    return np.sum(binned_psat) * 1000  # full sum over all energies in mJ

# %% [markdown]
# # TO DO have x-axis show E value not bin index (varies with # of psats

# %% [markdown]
# # Bare bones BO test
#
# max pulse energy is ~2-3 mJ, I can add that to the optimizer to avoid bad beams after fixing sig_pz

# %%
var_lim = [1 - 10 / 100, 1 + 10 / 100]
pbounds = {
    "var1": (l1_phase_init * var_lim[1], l1_phase_init * var_lim[0]),  # init -21.5
    "var1x": (l1x_phase_init * var_lim[1], l1x_phase_init * var_lim[0]),  # init -160.0
    "var2": (l2_phase_init * var_lim[1], l2_phase_init * var_lim[0]),
}  # init -33.5

optimizer = BayesianOptimization(f=evaluate, pbounds=pbounds, random_state=1)

optimizer.maximize(init_points=3, n_iter=30)
# Out:
# |   iter    |  target   |   var1    |   var1x   |   var2    |
# -------------------------------------------------------------
# JAN -> var1 = -21.856805379778933, var1x = -152.94961620985094, var2 = -36.84923368872379
# JAN Tao beamOn
# JAN BEAM_ON ... snparticle 1500
# JAN BEAM_ON ... beamon
# JAN BEAM_ON ... set ele O_L1 phase_deg=-21.856805379778933
# JAN BEAM_ON ... set ele K21_2 phase_deg=-152.94961620985094
# JAN BEAM_ON ... set ele O_L2 phase_deg=-36.84923368872379
# JAN BEAM_ON --- DONE ---
# JAN Tao saveBeam
2b75feb60e50>, 'MBLMH37': <ParticleGroup with 1495 particles at 0x2b75feb60880>, 'VVHXU37': <ParticleGroup with 1495 particles at 0x2b75feb60a30>, 'MBLMH38': <ParticleGroup with 1495 particles at 0x2b75feb60820>, 'MBLMH39': <ParticleGroup with 1495 particles at 0x2b75feb608e0>, 'MBLMH40': <ParticleGroup with 1495 particles at 0x2b75feb60ac0>, 'VVHXU40': <ParticleGroup with 1495 particles at 0x2b75feb60850>, 'MBLMH41': <ParticleGroup with 1495 particles at 0x2b75feb60910>, 'MBLMH42': <ParticleGroup with 1495 particles at 0x2b75feb60970>, 'MBLMH43': <ParticleGroup with 1495 particles at 0x2b75feb60b80>, 'VVHXU43': <ParticleGroup with 1495 particles at 0x2b75feb607c0>, 'MBLMH44': <ParticleGroup with 1495 particles at 0x2b75feb608b0>, 'MBLMH45': <ParticleGroup with 1495 particles at 0x2b75feb609d0>, 'MPHH': <ParticleGroup with 1495 particles at 0x2b762f8a2d90>, 'VVHXU45': <ParticleGroup with 1495 particles at 0x2b762f8a2460>, 'MBLMH46': <ParticleGroup with 1495 particles at 0x2b762f8a2490>, 'MUQH': <ParticleGroup with 1495 particles at 0x2b762f8a2430>, 'RWWAKE5H': <ParticleGroup with 1495 particles at 0x2b762f8a2f10>, 'HXRTERM': <ParticleGroup with 1495 particles at 0x2b762f8a22e0>}
# JAN -> n_part_alive = 1495
# JAN -> n_slice = 49
# JAN -> P = <ParticleGroup with 1495 particles at 0x2b762f8a22e0>
# JAN -> [(k, v.keys()) for k, v in slices.items()] = [('BEGUNDH', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MM3', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('PFILT1', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('DBMARK37', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('HXRSTART', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH13', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH14', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU14', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH15', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH16', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH17', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU17', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH18', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH19', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH20', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU20', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH22', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU22', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH23', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH24', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU24', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH25', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH26', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH27', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU27', dict_keys(['sigma_pz', 'mean_pz', 'average_current ...
# JAN -> time_slice = 2.4441259636415323e-15
# JAN -> [elem.shape for elem in lg_slice] = [(49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,)]
# JAN -> len(dZ) = 57
# JAN -> len(z) = 57 vs. len(markers) = 57
# JAN -> z = [0, 0.261, 0.261, 0.261, 0.355, 3.819, 7.832, 8.292, 11.845, 15.857, 19.87, 20.33, 23.883, 27.895, 31.908, 32.368, 39.933, 40.393, 43.946, 47.959, 48.418, 51.971, 55.984, 59.997, 60.456, 60.586, 63.958, 64.009, 68.022, 68.482, 72.035, 76.047, 80.06, 80.52, 84.073, 88.085, 92.098, 92.558, 96.111, 100.123, 100.583, 104.136, 108.149, 112.161, 112.621, 116.174, 120.187, 124.199, 124.659, 128.212, 132.225, 132.575, 132.684, 136.237, 136.33, 152.837, 152.837]
# JAN -> dZ = [0, 0.261, 0, 0, 0.09399999999999997, 3.464, 4.013, 0.45999999999999996, 3.553000000000001, 4.011999999999999, 4.013000000000002, 0.4599999999999973, 3.553000000000001, 4.0120000000000005, 4.013000000000002, 0.46000000000000085, 7.564999999999998, 0.46000000000000085, 3.5529999999999973, 4.013000000000005, 0.4589999999999961, 3.5529999999999973, 4.013000000000005, 4.012999999999998, 0.4590000000000032, 0.12999999999999545, 3.372, 0.05100000000000193, 4.013000000000005, 0.45999999999999375, 3.5529999999999973, 4.0120000000000005, 4.013000000000005, 0.45999999999999375, 3.5529999999999973, 4.0120000000000005, 4.013000000000005, 0
# JAN BEAM_ON ... beamon
# JAN BEAM_ON ... set ele O_L1 phase_deg=-22.349969937683092
# JAN BEAM_ON ... set ele K21_2 phase_deg=-171.30381149385238
# JAN BEAM_ON ... set ele O_L2 phase_deg=-36.231331415049056
# JAN BEAM_ON --- DONE ---
# JAN Tao saveBeam
# JAN -> P_data = {'BEGUNDH': <ParticleGroup with 1500 particles at 0x2b763fa57d60>, 'MM3': <ParticleGroup with 1500 particles at 0x2b763fa57400>, 'PFILT1': <ParticleGroup with 1500 particles at 0x2b763fa47a60>, 'DBMARK37': <ParticleGroup with 1500 particles at 0x2b7541656310>, 'HXRSTART': <ParticleGroup with 1500 particles at 0x2b763fa407c0>, 'MBLMH13': <ParticleGroup with 1500 particles at 0x2b75feb607f0>, 'MBLMH14': <ParticleGroup with 1500 particles at 0x2b75feb60b20>, 'VVHXU14': <ParticleGroup with 1500 particles at 0x2b75feb60cd0>, 'MBLMH15': <ParticleGroup with 1500 particles at 0x2b75feb60b80>, 'MBLMH16': <ParticleGroup with 1500 particles at 0x2b75feb608b0>, 'MBLMH17': <ParticleGroup with 1500 particles at 0x2b75feb60940>, 'VVHXU17': <ParticleGroup with 1500 particles at 0x2b762f8d3370>, 'MBLMH18': <ParticleGroup with 1500 particles at 0x2b762f8d36a0>, 'MBLMH19': <ParticleGroup with 1500 particles at 0x2b762f8d3b50>, 'MBLMH20': <ParticleGroup with 1500 particles at 0x2b762f8d3e80>, 'VVHXU20': <ParticleGroup with 1500 particles at 0x2b762f8d3190>, 'MBLMH22': <ParticleGroup with 1500 particles at 0x2b762f8d3e50>, 'VVHXU22': <ParticleGroup with 1500 particles at 0x2b762f8d3700>, 'MBLMH23': <ParticleGroup with 1500 particles at 0x2b762f8d3580>, 'MBLMH24': <ParticleGroup with 1500 particles at 0x2b762f8d3a30>, 'VVHXU24': <ParticleGroup with 1500 particles at 0x2b762f8d3fa0>, 'MBLMH25': <ParticleGroup with 1500 particles at 0x2b762f8d3d60>, 'MBLMH26': <ParticleGroup with 1500 particles at 0x2b762f8d3f10>, 'MBLMH27': <ParticleGroup with 1500 particles at 0x2b762f8d3220>, 'VVHXU27': <ParticleGroup with 1500 particles at 0x2b762f8d31f0>, 'HXRSSBEG': <ParticleGroup with 1500 particles at 0x2b762f8d3640>, 'HXRSSEND': <ParticleGroup with 1500 particles at 0x2b762f8d3340>, 'MBLMH28': <ParticleGroup with 1500 particles at 0x2b762f8d3310>, 'MBLMH29': <ParticleGroup with 1500 particles at 0x2b762f8d3520>, 'VVHXU29': <ParticleGroup with 1500 particles at 0x2b762f8d3550>, 'MBLMH30': <ParticleGroup with 1500 particles at 0x2b762f8d3820>, 'MBLMH31': <ParticleGroup with 1500 particles at 0x2b762f8d37c0>, 'MBLMH32': <ParticleGroup with 1500 particles at 0x2b762f8d3670>, 'VVHXU32': <ParticleGroup with 1500 particles at 0x2b762f8d3ca0>, 'MBLMH33': <ParticleGroup with 1500 particles at 0x2b762f8d3790>, 'MBLMH34': <ParticleGroup with 1500 particles at 0x2b762f8d3c40>, 'MBLMH35': <ParticleGroup with 1500 particles at 0x2b762f8d3400>, 'VVHXU35': <ParticleGroup with 1500 particles at 0x2b762f8d3430>, 'MBLMH36': <ParticleGroup with 1500 particles at 0x2b762f8d34f0>, 'MBLMH37': <ParticleGroup with 1500 particles at 0x2b762f8d3cd0>, 'VVHXU37': <ParticleGroup with 1500 particles at 0x2b762f8d3af0>, 'MBLMH38': <ParticleGroup with 1500 particles at 0x2b762f8d3f40>, 'MBLMH39': <ParticleGroup with 1500 particles at 0x2b762f8d3c10>, 'MBLMH40': <ParticleGroup with 1500 particles at 0x2b762f8d3d00>, 'VVHXU40': <ParticleGroup with 1500 particles at 0x2b762f8d3070>, 'MBLMH41': <ParticleGroup with 1500 particles at 0x2b762f8d3040>, 'MBLMH42': <ParticleGroup with 1500 particles at 0x2b75feadfbb0>, 'MBLMH43': <ParticleGroup with 1500 particles at 0x2b762f8d3a90>, 'VVHXU43': <ParticleGroup with 1500 particles at 0x2b762f8d39a0>, 'MBLMH44': <ParticleGroup with 1500 particles at 0x2b762f8d3940>, 'MBLMH45': <ParticleGroup with 1500 particles at 0x2b762f8d3100>, 'MPHH': <ParticleGroup with 1500 particles at 0x2b762f8d3850>, 'VVHXU45': <ParticleGroup with 1500 particles at 0x2b762f8d3a60>, 'MBLMH46': <ParticleGroup with 1500 particles at 0x2b762f8d3970>, 'MUQH': <ParticleGroup with 1500 particles at 0x2b762f8a2490>, 'RWWAKE5H': <ParticleGroup with 1500 particles at 0x2b762f8a2460>, 'HXRTERM': <ParticleGroup with 1500 particles at 0x2b762f8a2d90>}
# JAN -> n_part_alive = 1500
# JAN -> n_slice = 50
# JAN -> P = <ParticleGroup with 1500 particles at 0x2b762f8a2d90>
# JAN -> [(k, v.keys()) for k, v in slices.items()] = [('BEGUNDH', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MM3', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('PFILT1', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('DBMARK37', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('HXRSTART', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH13', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH14', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU14', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH15', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH16', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH17', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU17', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH18', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH19', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH20', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU20', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH22', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU22', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH23', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH24', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU24', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH25', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH26', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH27', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU27', dict_keys(['sigma_pz', 'mean_pz', 'average_current ...
# JAN -> time_slice = 6.171460877871151e-15
# JAN -> [elem.shape for elem in lg_slice] = [(50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,)]
# JAN -> len(dZ) = 57
# JAN -> len(z) = 57 vs. len(markers) = 57
# JAN -> z = [0, 0.261, 0.261, 0.261, 0.355, 3.819, 7.832, 8.292, 11.845, 15.857, 19.87, 20.33, 23.883, 27.895, 31.908, 32.368, 39.933, 40.393, 43.946, 47.959, 48.418, 51.971, 55.984, 59.997, 60.456, 60.586, 63.958, 64.009, 68.022, 68.482, 72.035, 76.047, 80.06, 80.52, 84.073, 88.085, 92.098, 92.558, 96.111, 100.123, 100.583, 104.136, 108.149, 112.161, 112.621, 116.174, 120.187, 124.199, 124.659, 128.212, 132.225, 132.575, 132.684, 136.237, 136.33, 152.837, 152.837]
# JAN -> dZ = [0, 0.261, 0, 0, 0.09399999999999997, 3.464, 4.013, 0.45999999999999996, 3.553000000000001, 4.011999999999999, 4.013000000000002, 0.4599999999999973, 3.553000000000001, 4.0120000000000005, 4.013000000000002, 0.46000000000000085, 7.564999999999998, 0.46000000000000085, 3.5529999999999973, 4.013000000000005, 0.4589999999999961, 3.5529999999999973, 4.013000000000005, 4.012999999999998, 0.4590000000000032, 0.12999999999999545, 3.372, 0.05100000000000193, 4.013000000000005, 0.45999999999999375, 3.5529999999999973, 4.0120000000000005, 4.013000000000005, 0.45999999999999375, 3.5529999999999973, 4.0120000000000005, 4.013000000000005, 0
# | 2         | 3.04      | -22.35    | -171.3    | -36.23    |
# JAN -> var1 = -22.849081091076016, var1x = -164.94205673462247, var2 = -34.191657922654514
# JAN Tao beamOn
# JAN BEAM_ON ... snparticle 1500
# Passing RuntimeError
# JAN Tao saveBeam
# JAN -> P_data = {'BEGUNDH': <ParticleGroup with 1500 particles at 0x2b7768abc100>, 'MM3': <ParticleGroup with 1500 particles at 0x2b7768ab3f70>, 'PFILT1': <ParticleGroup with 1500 particles at 0x2b7768ab3d00>, 'DBMARK37': <ParticleGroup with 1500 particles at 0x2b7768ab3eb0>, 'HXRSTART': <ParticleGroup with 1500 particles at 0x2b7768ab37f0>, 'MBLMH13': <ParticleGroup with 1500 particles at 0x2b7768ab38b0>, 'MBLMH14': <ParticleGroup with 1500 particles at 0x2b763fbaed60>, 'VVHXU14': <ParticleGroup with 1500 particles at 0x2b763fbaecd0>, 'MBLMH15': <ParticleGroup with 1500 particles at 0x2b763fbaed30>, 'MBLMH16': <ParticleGroup with 1500 particles at 0x2b763fbae550>, 'MBLMH17': <ParticleGroup with 1500 particles at 0x2b763fbaedc0>, 'VVHXU17': <ParticleGroup with 1500 particles at 0x2b763fbbe4c0>, 'MBLMH18': <ParticleGroup with 1500 particles at 0x2b7768ac4400>, 'MBLMH19': <ParticleGroup with 1500 particles at 0x2b7768ac4850>, 'MBLMH20': <ParticleGroup with 1500 particles at 0x2b7768ac4460>, 'VVHXU20': <ParticleGroup with 1500 particles at 0x2b7768ac4910>, 'MBLMH22': <ParticleGroup with 1500 particles at 0x2b7768ac4970>, 'VVHXU22': <ParticleGroup with 1500 particles at 0x2b7768ac49d0>, 'MBLMH23': <ParticleGroup with 1500 particles at 0x2b7768ac4a30>, 'MBLMH24': <ParticleGroup with 1500 particles at 0x2b7768ac4a90>, 'VVHXU24': <ParticleGroup with 1500 particles at 0x2b7768ac4af0>, 'MBLMH25': <ParticleGroup with 1500 particles at 0x2b7768ac4b50>, 'MBLMH26': <ParticleGroup with 1500 particles at 0x2b7768ac4bb0>, 'MBLMH27': <ParticleGroup with 1500 particles at 0x2b7768ac4c10>, 'VVHXU27': <ParticleGroup with 1500 particles at 0x2b7768ac4c70>, 'HXRSSBEG': <ParticleGroup with 1500 particles at 0x2b7768ac4cd0>, 'HXRSSEND': <ParticleGroup with 1500 particles at 0x2b7768ac4d30>, 'MBLMH28': <ParticleGroup with 1500 particles at 0x2b7768ac4d90>, 'MBLMH29': <ParticleGroup with 1500 particles at 0x2b7768ac4df0>, 'VVHXU29': <ParticleGroup with 1500 particles at 0x2b7768ac4e50>, 'MBLMH30': <ParticleGroup with 1500 particles at 0x2b7768ac4eb0>, 'MBLMH31': <ParticleGroup with 1500 particles at 0x2b7768ac4f10>, 'MBLMH32': <ParticleGroup with 1500 particles at 0x2b7768ac4f70>, 'VVHXU32': <ParticleGroup with 1500 particles at 0x2b7768ac4fd0>, 'MBLMH33': <ParticleGroup with 1500 particles at 0x2b7768ac4340>, 'MBLMH34': <ParticleGroup with 1500 particles at 0x2b7768ac4370>, 'MBLMH35': <ParticleGroup with 1500 particles at 0x2b7768ac43d0>, 'VVHXU35': <ParticleGroup with 1500 particles at 0x2b7768ac4430>, 'MBLMH36': <ParticleGroup with 1500 particles at 0x2b7768ac4490>, 'MBLMH37': <ParticleGroup with 1500 particles at 0x2b7768ac44f0>, 'VVHXU37': <ParticleGroup with 1500 particles at 0x2b7768ac4550>, 'MBLMH38': <ParticleGroup with 1500 particles at 0x2b7768ac45b0>, 'MBLMH39': <ParticleGroup with 1500 particles at 0x2b7768ac4610>, 'MBLMH40': <ParticleGroup with 1500 particles at 0x2b7768ac4670>, 'VVHXU40': <ParticleGroup with 1500 particles at 0x2b7768ac46d0>, 'MBLMH41': <ParticleGroup with 1500 particles at 0x2b7768ac4730>, 'MBLMH42': <ParticleGroup with 1500 particles at 0x2b7768ac47f0>, 'MBLMH43': <ParticleGroup with 1500 particles at 0x2b7768ac48b0>, 'VVHXU43': <ParticleGroup with 1500 particles at 0x2b7768ac43a0>, 'MBLMH44': <ParticleGroup with 1500 particles at 0x2b7768ac4790>, 'MBLMH45': <ParticleGroup with 1500 particles at 0x2b7768b050d0>, 'MPHH': <ParticleGroup with 1500 particles at 0x2b7768b051f0>, 'VVHXU45': <ParticleGroup with 1500 particles at 0x2b7768b05250>, 'MBLMH46': <ParticleGroup with 1500 particles at 0x2b7768b052b0>, 'MUQH': <ParticleGroup with 1500 particles at 0x2b7768b05310>, 'RWWAKE5H': <ParticleGroup with 1500 particles at 0x2b7768b05370>, 'HXRTERM': <ParticleGroup with 1500 particles at 0x2b7768b053d0>}
# JAN -> n_part_alive = 1500
# JAN -> n_slice = 50
# JAN -> P = <ParticleGroup with 1500 particles at 0x2b7768b053d0>
# JAN -> [(k, v.keys()) for k, v in slices.items()] = [('BEGUNDH', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MM3', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('PFILT1', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('DBMARK37', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('HXRSTART', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH13', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH14', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU14', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH15', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH16', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH17', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU17', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH18', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH19', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH20', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU20', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH22', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU22', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH23', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH24', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU24', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH25', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH26', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH27', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU27', dict_keys(['sigma_pz', 'mean_pz', 'average_current ...
# JAN -> time_slice = 6.171460877871151e-15
# JAN -> [elem.shape for elem in lg_slice] = [(50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,), (50,)]
# JAN -> len(dZ) = 57
# JAN -> len(z) = 57 vs. len(markers) = 57
# JAN -> z = [0, 0.261, 0.261, 0.261, 0.355, 3.819, 7.832, 8.292, 11.845, 15.857, 19.87, 20.33, 23.883, 27.895, 31.908, 32.368, 39.933, 40.393, 43.946, 47.959, 48.418, 51.971, 55.984, 59.997, 60.456, 60.586, 63.958, 64.009, 68.022, 68.482, 72.035, 76.047, 80.06, 80.52, 84.073, 88.085, 92.098, 92.558, 96.111, 100.123, 100.583, 104.136, 108.149, 112.161, 112.621, 116.174, 120.187, 124.199, 124.659, 128.212, 132.225, 132.575, 132.684, 136.237, 136.33, 152.837, 152.837]
# | 3         | 3.04      | -22.85    | -164.9    | -34.19    |
# JAN -> var1 = -19.35, var1x = -170.61357215820107, var2 = -30.150000000000002
# JAN Tao beamOn
# JAN BEAM_ON ... snparticle 1500
# JAN BEAM_ON ... beamon
# JAN BEAM_ON ... set ele O_L1 phase_deg=-19.35
# JAN BEAM_ON ... set ele K21_2 phase_deg=-170.61357215820107
# JAN BEAM_ON ... set ele O_L2 phase_deg=-30.150000000000002
# JAN BEAM_ON --- DONE ---
# JAN Tao saveBeam
# ...
# | 5         | 0.6493    | -23.0     | -165.2    | -33.83    |
# JAN -> var1 = -21.0878688862306, var1x = -167.6472029343786, var2 = -31.846915994685517
# JAN Tao beamOn
# JAN BEAM_ON ... snparticle 1500
# JAN BEAM_ON ... beamon
# JAN BEAM_ON ... set ele O_L1 phase_deg=-21.0878688862306
# JAN BEAM_ON ... set ele K21_2 phase_deg=-167.6472029343786
# JAN BEAM_ON ... set ele O_L2 phase_deg=-31.846915994685517
# JAN BEAM_ON --- DONE ---
# JAN Tao saveBeam
# JAN -> P_data = {'BEGUNDH': <ParticleGroup with 1497 particles at 0x2b7784603dc0>, 'MM3': <ParticleGroup with 1497 particles at 0x2b78134e7460>, 'PFILT1': <ParticleGroup with 1497 particles at 0x2b7768ac4af0>, 'DBMARK37': <ParticleGroup with 1497 particles at 0x2b7768ac4820>, 'HXRSTART': <ParticleGroup with 1497 particles at 0x2b7768ac4cd0>, 'MBLMH13': <ParticleGroup with 1497 particles at 0x2b7768ac4f10>, 'MBLMH14': <ParticleGroup with 1497 particles at 0x2b7768ac4e50>, 'VVHXU14': <ParticleGroup with 1497 particles at 0x2b7768ac4df0>, 'MBLMH15': <ParticleGroup with 1497 particles at 0x2b7768ac43d0>, 'MBLMH16': <ParticleGroup with 1497 particles at 0x2b7768ac4ca0>, 'MBLMH17': <ParticleGroup with 1497 particles at 0x2b7768ac4370>, 'VVHXU17': <ParticleGroup with 1497 particles at 0x2b7768ac4610>, 'MBLMH18': <ParticleGroup with 1497 particles at 0x2b7768ac4490>, 'MBLMH19': <ParticleGroup with 1497 particles at 0x2b7768ac4d60>, 'MBLMH20': <ParticleGroup with 1497 particles at 0x2b7768ac4550>, 'VVHXU20': <ParticleGroup with 1497 particles at 0x2b7768ac4dc0>, 'MBLMH22': <ParticleGroup with 1497 particles at 0x2b7768ac4f40>, 'VVHXU22': <ParticleGroup with 1497 particles at 0x2b7768ac4be0>, 'MBLMH23': <ParticleGroup with 1497 particles at 0x2b7768ac45b0>, 'MBLMH24': <ParticleGroup with 1497 particles at 0x2b7768ac4ac0>, 'VVHXU24': <ParticleGroup with 1497 particles at 0x2b77844d2640>, 'MBLMH25': <ParticleGroup with 1497 particles at 0x2b7803f8f4c0>, 'MBLMH26': <ParticleGroup with 1497 particles at 0x2b7768ac46d0>, 'MBLMH27': <ParticleGroup with 1497 particles at 0x2b7768ac49a0>, 'VVHXU27': <ParticleGroup with 1497 particles at 0x2b7768ac4d00>, 'HXRSSBEG': <ParticleGroup with 1497 particles at 0x2b778461f0d0>, 'HXRSSEND': <ParticleGroup with 1497 particles at 0x2b778461f070>, 'MBLMH28': <ParticleGroup with 1497 particles at 0x2b778461f2e0>, 'MBLMH29': <ParticleGroup with 1497 particles at 0x2b778461f250>, 'VVHXU29': <ParticleGroup with 1497 particles at 0x2b778461f1f0>, 'MBLMH30': <ParticleGroup with 1497 particles at 0x2b778461f100>, 'MBLMH31': <ParticleGroup with 1497 particles at 0x2b778461f130>, 'MBLMH32': <ParticleGroup with 1497 particles at 0x2b778461f400>, 'VVHXU32': <ParticleGroup with 1497 particles at 0x2b778461f460>, 'MBLMH33': <ParticleGroup with 1497 particles at 0x2b7813583f10>, 'MBLMH34': <ParticleGroup with 1497 particles at 0x2b7813583790>, 'MBLMH35': <ParticleGroup with 1497 particles at 0x2b778461f040>, 'VVHXU35': <ParticleGroup with 1497 particles at 0x2b78135837c0>, 'MBLMH36': <ParticleGroup with 1497 particles at 0x2b78135837f0>, 'MBLMH37': <ParticleGroup with 1497 particles at 0x2b78134f9490>, 'VVHXU37': <ParticleGroup with 1497 particles at 0x2b781358f280>, 'MBLMH38': <ParticleGroup with 1497 particles at 0x2b781358f2e0>, 'MBLMH39': <ParticleGroup with 1497 particles at 0x2b781358f340>, 'MBLMH40': <ParticleGroup with 1497 particles at 0x2b781358f3a0>, 'VVHXU40': <ParticleGroup with 1497 particles at 0x2b781358f400>, 'MBLMH41': <ParticleGroup with 1497 particles at 0x2b781358f460>, 'MBLMH42': <ParticleGroup with 1497 particles at 0x2b781358f4c0>, 'MBLMH43': <ParticleGroup with 1497 particles at 0x2b781358f520>, 'VVHXU43': <ParticleGroup with 1497 particles at 0x2b781358f580>, 'MBLMH44': <ParticleGroup with 1497 particles at 0x2b781358f5e0>, 'MBLMH45': <ParticleGroup with 1497 particles at 0x2b781358f640>, 'MPHH': <ParticleGroup with 1497 particles at 0x2b781358f6a0>, 'VVHXU45': <ParticleGroup with 1497 particles at 0x2b781358f700>, 'MBLMH46': <ParticleGroup with 1497 particles at 0x2b781358f760>, 'MUQH': <ParticleGroup with 1497 particles at 0x2b781358f7c0>, 'RWWAKE5H': <ParticleGroup with 1497 particles at 0x2b781358f820>, 'HXRTERM': <ParticleGroup with 1497 particles at 0x2b781358f880>}
# JAN -> n_part_alive = 1497
# JAN -> n_slice = 49
# JAN -> P = <ParticleGroup with 1497 particles at 0x2b781358f880>
# JAN -> [(k, v.keys()) for k, v in slices.items()] = [('BEGUNDH', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MM3', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('PFILT1', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('DBMARK37', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('HXRSTART', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH13', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH14', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU14', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH15', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH16', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH17', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU17', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH18', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH19', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH20', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU20', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH22', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU22', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH23', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH24', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU24', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH25', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH26', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('MBLMH27', dict_keys(['sigma_pz', 'mean_pz', 'average_current', 'norm_emit_x', 'norm_emit_y', 'mean_px', 'mean_x', 'mean_py', 'mean_y', 'sigma_x', 'sigma_y'])), ('VVHXU27', dict_keys(['sigma_pz', 'mean_pz', 'average_current ...
# JAN -> time_slice = 4.301028879077114e-14
# JAN -> [elem.shape for elem in lg_slice] = [(49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,), (49,)]
# JAN -> len(dZ) = 57
# JAN -> len(z) = 57 vs. len(markers) = 57
# JAN -> z = [0, 0.261, 0.261, 0.261, 0.355, 3.819, 7.832, 8.292, 11.845, 15.857, 19.87, 20.33, 23.883, 27.895, 31.908, 32.368, 39.933, 40.393, 43.946, 47.959, 48.418, 51.971, 55.984, 59.997, 60.456, 60.586, 63.958, 64.009, 68.022, 68.482, 72.035, 76.047, 80.06, 80.52, 84.073, 88.085, 92.098, 92.558, 96.111, 100.123, 100.583, 104.136, 108.149, 112.161, 112.621, 116.174, 120.187, 124.199, 124.659, 128.212, 132.225, 132.575, 132.684, 136.237, 136.33, 152.837, 152.837]
# JAN -> dZ = [0, 0.261, 0, 0, 0.09399999999999997, 3.464, 4.013, 0.45999999999999996, 3.553000000000001, 4.011999999999999, 4.013000000000002, 0.4599999999999973, 3.553000000000001, 4.0120000000000005, 4.013000000000002, 0.46000000000000085, 7.564999999999998, 0.46000000000000085, 3.5529999999999973, 4.013000000000005, 0.4589999999999961, 3.5529999999999973, 4.013000000000005, 4.012999999999998, 0.4590000000000032, 0.12999999999999545, 3.372, 0.05100000000000193, 4.013000000000005, 0.45999999999999375, 3.5529999999999973, 4.0120000000000005, 4.013000000000005, 0.45999999999999375, 3.5529999999999973, 4.0120000000000005, 4.013000000000005, 0.46000000000000796, 3.5529999999999973, 4.0120000000000005, 0.45999999999999375, 3.5529999999999973, 4.013000000000005, 4.0120000000000005, 0.45999999999999375, 3.5530000000000115, 4.012999999999991, 4.0120000000000005, 0.46000000000000796, 3.552999999999983, 4.013000000000005, 0.3499999999999943, 0.10900000000000887, 3.5529999999999973, 0.09300000000001774, 16.506999999999977, 0]
# slice 0 did not saturate.
# slice 7 did not saturate.
# slice 10 did not saturate.
# slice 13 did not saturate.
# JAN -> lg_cumul_slice = [[0.0, 8.88692716467343e-09, 8.88692716467343e-09, 8.88692716467343e-09, 1.2113550825647262e-08, 1.6348975717307004e-07, 3.787081677715464e-07, 4.038365369511843e-07, 6.182720450486953e-07, 8.667415277456684e-07, 1.097579328361397e-06, 1.1237356428489966e-06, 1.2940651700540023e-06, 1.4355744801131643e-06, 1.5303794291876542e-06, 1.5406606395387275e-06, 1.6477511796292023e-06, 1.65433546741294e-06, 1.7134002375160395e-06, 1.8028720140964098e-06, 1.8135753948090433e-06, 1.922339710408935e-06, 2.083527097341622e-06, 2.28224726632288e-06, 2.305422601318838e-06, 2.3120218820843205e-06, 2.502531623194722e-06, 2.5054160550177573e-06, 2.744021034535256e-06, 2.7714415467374815e-06, 2.973530292513328e-06, 3.169726271649746e-06, 3.320496195763181e-06, 3.3370330090761146e-06,
 39.933, 39.933, 39.933, 39.933, 39.933, 39.933, 39.933, 39.933, 39.933, 39.933, 39.933, 39.933, 39.933, 43.946, 39.933, 39.933, 31.908, 39.933, 31.908, 39.933, 39.933, 43.946, 31.908, 40.393, 40.393, 43.946, 92.558, 96.111, 55.984, 68.022]
# JAN -> zsat_idx = [14, 13, 14, 20, 22, 47, 34, 26, 16, 42, 13, 15, 18, 16, 14, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 16, 18, 16, 16, 14, 16, 14, 16, 16, 18, 14, 17, 17, 18, 37, 38, 22, 28]
# JAN -> lg_avg = [1.7726666666666668, 1.5497222222222222, 1.7726666666666668, 2.689888888888889, 3.110222222222222, 6.899944444444444, 4.6707222222222216, 3.5532222222222223, 2.2185, 6.008277777777778, 1.5497222222222222, 1.7982222222222224, 2.4414444444444445, 2.2185, 1.7726666666666668, 2.2185, 2.2185, 2.2185, 2.2185, 2.2185, 2.2185, 2.2185, 2.2185, 2.2185, 2.2185, 2.2185, 2.2185, 2.2185, 2.4414444444444445, 2.2185, 2.2185, 1.7726666666666668, 2.2185, 1.7726666666666668, 2.2185, 2.2185, 2.4414444444444445, 1.7726666666666668, 2.2440555555555557, 2.2440555555555557, 2.4414444444444445, 5.142111111111111, 5.3395, 3.110222222222222, 3.7790000000000004]
# | 6         | 18.11     | -21.09    | -167.6    | -31.85    |
# JAN -> var1 = -20.4084537934856, var1x = -167.22204224687746, var2 = -31.530040537660685
# JAN Tao beamOn
# JAN BEAM_ON ... snparticle 1500

# %%
optimizer.maximize(init_points=1, n_iter=10)
# Out:
# |   iter    |  target   |   var1    |   var1x   |   var2    |
# -------------------------------------------------------------
# Passing RuntimeError
# slice 0 did not saturate.
# slice 49 did not saturate.
# |  34       |  2.184    | -21.33    | -162.6    | -32.26    |
# |  35       |  3.966    | -23.37    | -144.3    | -36.72    |
# Passing RuntimeError
# slice 0 did not saturate.
# slice 49 did not saturate.
# |  36       |  1.905    | -23.21    | -174.2    | -34.37    |
# Passing RuntimeError
# slice 0 did not saturate.
# slice 49 did not saturate.
# |  37       |  1.887    | -21.77    | -169.8    | -36.34    |
# Passing RuntimeError
# slice 0 did not saturate.
# slice 49 did not saturate.
# |  38       |  1.902    | -23.47    | -172.3    | -33.49    |
# Passing RuntimeError
# slice 0 did not saturate.
# slice 49 did not saturate.
# |  39       |  2.24     | -23.26    | -144.5    | -36.58    |
# |  40       |  3.324    | -21.98    | -144.2    | -36.55    |
# Passing RuntimeError
# slice 0 did not saturate.
# slice 49 did not saturate.
# |  41       |  1.934    | -23.49    | -144.2    | -36.42    |
# slice 0 did not saturate.
# |  42       |  3.28     | -23.35    | -144.5    | -36.84    |
# Passing RuntimeError
# slice 0 did not saturate.
# |  43       |  3.138    | -21.75    | -144.4    | -36.52    |
# Passing RuntimeError
# /sdf/home/s/smiskov/sw/conda/envs/felsim/lib/python3.7/site-packages/pmd_beamphysics/plot.py:151: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(**kwargs)
# slice 0 did not saturate.
# slice 49 did not saturate.
# |  44       |  1.891    | -22.55    | -148.9    | -35.97    |
# =============================================================
